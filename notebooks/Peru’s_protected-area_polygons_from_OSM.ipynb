# %%
import requests
import json
import geopandas as gpd
from shapely.geometry import Polygon, MultiPolygon
import pandas as pd
import time
from typing import Dict, List, Any

def build_overpass_query() -> str:
    """
    Construye la consulta Overpass para obtener áreas protegidas del Perú.
    Sigue las mejores prácticas mencionadas en la documentación de OSM API.
    
    Returns:
        str: Consulta Overpass formateada
    """
    # Bbox aproximado de Perú: [sur, oeste, norte, este]
    peru_bbox = "-18.5,-81.5,0.5,-68.5"
    
    query = f"""
    [out:json][timeout:300][maxsize:1073741824][bbox:{peru_bbox}];
    (
      // Consulta específica para áreas protegidas siguiendo estándares OSM
      // Relaciones con boundary=protected_area (estándar principal)
      relation["boundary"="protected_area"];
      
      // Ways que forman límites de áreas protegidas
      way["boundary"="protected_area"];
      
      // Reservas naturales (clasificación leisure)
      relation["leisure"="nature_reserve"];
      way["leisure"="nature_reserve"];
      
      // Cualquier elemento con clasificación de protección IUCN
      relation["protect_class"~"^[1-6]$|^I[I-V]?$"];
      way["protect_class"~"^[1-6]$|^I[I-V]?$"];
      
      // Elementos específicos para Perú con designation
      relation["designation"~"Parque Nacional|Reserva Nacional|Santuario Nacional|Santuario Histórico|Reserva Paisajística|Refugio de Vida Silvestre|Bosque de Protección|Coto de Caza|Zona Reservada|Área de Conservación"];
      way["designation"~"Parque Nacional|Reserva Nacional|Santuario Nacional|Santuario Histórico|Reserva Paisajística|Refugio de Vida Silvestre|Bosque de Protección|Coto de Caza|Zona Reservada|Área de Conservación"];
    );
    (._;>;);
    out geom;
    """
    return query

def fetch_osm_data(query: str, max_retries: int = 3) -> Dict[str, Any]:
    """
    Obtiene datos de OSM usando la API Overpass siguiendo buenas prácticas.
    
    Args:
        query: Consulta Overpass
        max_retries: Número máximo de reintentos
        
    Returns:
        Dict con los datos de respuesta de OSM
    """
    # Lista de servidores Overpass para balancear carga
    overpass_urls = [
        "https://overpass-api.de/api/interpreter",
        "https://overpass.kumi.systems/api/interpreter",
        "https://overpass.openstreetmap.ru/api/interpreter"
    ]
    
    # Headers para identificar el cliente
    headers = {
        'User-Agent': 'Peru Protected Areas Study/1.0 (Educational Purpose)'
    }
    
    for attempt in range(max_retries):
        # Rotar entre servidores
        url = overpass_urls[attempt % len(overpass_urls)]
        
        try:
            print(f"Realizando consulta a Overpass API (intento {attempt + 1}/{max_retries})...")
            print(f"Servidor: {url}")
            
            # Respetar límites de la API con timeout apropiado
            response = requests.post(
                url, 
                data=query, 
                headers=headers,
                timeout=300
            )
            response.raise_for_status()
            
            data = response.json()
            print(f"Consulta exitosa. Elementos obtenidos: {len(data.get('elements', []))}")
            return data
            
        except requests.exceptions.RequestException as e:
            print(f"Error en intento {attempt + 1} con {url}: {e}")
            if attempt < max_retries - 1:
                wait_time = 5 * (attempt + 1)  # Backoff exponencial
                print(f"Esperando {wait_time} segundos antes del siguiente intento...")
                time.sleep(wait_time)
            else:
                raise
    
    return {}

def filter_protected_areas(elements: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    """
    Filtra las áreas protegidas según criterios específicos.
    
    Criterios de filtrado:
    - protect_class en {"1", "2", "3", "4", "5", "6"} (IUCN categories)
    - boundary=protected_area
    - leisure=nature_reserve
    
    Args:
        elements: Lista de elementos de OSM
        
    Returns:
        Lista filtrada de elementos
    """
    # Clases de protección aceptadas (IUCN y otras categorías relevantes)
    accepted_protect_classes = {"1", "2", "3", "4", "5", "6", "1a", "1b", "II", "III", "IV", "V", "VI"}
    
    filtered_elements = []
    
    for element in elements:
        tags = element.get('tags', {})
        
        # Criterios de filtrado
        has_boundary_protected = tags.get('boundary') == 'protected_area'
        has_leisure_nature = tags.get('leisure') == 'nature_reserve'
        has_valid_protect_class = tags.get('protect_class', '').lower() in [pc.lower() for pc in accepted_protect_classes]
        
        # Filtros adicionales para parques nacionales, reservas de vida silvestre y forestales
        designation = tags.get('designation', '').lower()
        name = tags.get('name', '').lower()
        
        is_national_park = 'parque nacional' in designation or 'national park' in designation
        is_wildlife_reserve = 'reserva' in designation and ('vida silvestre' in designation or 'wildlife' in designation)
        is_forest_reserve = 'reserva forestal' in designation or 'forest reserve' in designation
        is_nature_reserve = 'reserva natural' in designation or 'nature reserve' in designation
        
        # Aplicar filtros
        if (has_boundary_protected or has_leisure_nature or has_valid_protect_class or 
            is_national_park or is_wildlife_reserve or is_forest_reserve or is_nature_reserve):
            
            filtered_elements.append(element)
            print(f"Aceptado: {tags.get('name', 'Sin nombre')} - "
                  f"protect_class: {tags.get('protect_class', 'N/A')}, "
                  f"designation: {tags.get('designation', 'N/A')}")
    
    print(f"\nElementos filtrados: {len(filtered_elements)} de {len(elements)} originales")
    return filtered_elements

def create_polygon_from_way(way: Dict[str, Any]) -> Polygon:
    """
    Crea un polígono a partir de un way de OSM.
    
    Args:
        way: Elemento way de OSM con geometría
        
    Returns:
        Shapely Polygon
    """
    if 'geometry' not in way:
        return None
        
    coords = [(node['lon'], node['lat']) for node in way['geometry']]
    
    # Asegurar que el polígono esté cerrado
    if len(coords) > 2 and coords[0] != coords[-1]:
        coords.append(coords[0])
    
    if len(coords) >= 4:  # Mínimo para un polígono válido
        return Polygon(coords)
    
    return None

def create_multipolygon_from_relation(relation: Dict[str, Any], ways_dict: Dict[int, Dict]) -> MultiPolygon:
    """
    Crea un MultiPolygon a partir de una relación de OSM.
    
    Args:
        relation: Elemento relation de OSM
        ways_dict: Diccionario de ways indexado por ID
        
    Returns:
        Shapely MultiPolygon o Polygon
    """
    outer_ways = []
    inner_ways = []
    
    for member in relation.get('members', []):
        if member['type'] == 'way' and member['ref'] in ways_dict:
            way = ways_dict[member['ref']]
            if member.get('role') == 'outer':
                outer_ways.append(way)
            elif member.get('role') == 'inner':
                inner_ways.append(way)
    
    polygons = []
    for way in outer_ways:
        poly = create_polygon_from_way(way)
        if poly:
            polygons.append(poly)
    
    if polygons:
        if len(polygons) == 1:
            return polygons[0]
        else:
            return MultiPolygon(polygons)
    
    return None

def convert_to_geodataframe(elements: List[Dict[str, Any]]) -> gpd.GeoDataFrame:
    """
    Convierte elementos de OSM a GeoDataFrame.
    
    Args:
        elements: Lista de elementos filtrados de OSM
        
    Returns:
        GeoDataFrame con las áreas protegidas
    """
    rows = []
    ways_dict = {}
    
    # Crear diccionario de ways para las relaciones
    for element in elements:
        if element['type'] == 'way':
            ways_dict[element['id']] = element
    
    for element in elements:
        tags = element.get('tags', {})
        geometry = None
        
        if element['type'] == 'way':
            geometry = create_polygon_from_way(element)
        elif element['type'] == 'relation':
            geometry = create_multipolygon_from_relation(element, ways_dict)
        
        if geometry and not geometry.is_empty:
            row = {
                'osm_id': element['id'],
                'osm_type': element['type'],
                'name': tags.get('name', ''),
                'name_es': tags.get('name:es', ''),
                'designation': tags.get('designation', ''),
                'protect_class': tags.get('protect_class', ''),
                'boundary': tags.get('boundary', ''),
                'leisure': tags.get('leisure', ''),
                'operator': tags.get('operator', ''),
                'website': tags.get('website', ''),
                'wikidata': tags.get('wikidata', ''),
                'area_km2': geometry.area * 111.32 * 111.32,  # Aproximación área en km²
                'geometry': geometry
            }
            rows.append(row)
    
    if rows:
        gdf = gpd.GeoDataFrame(rows, crs='EPSG:4326')
        return gdf
    else:
        # Crear GeoDataFrame vacío con las columnas correctas
        return gpd.GeoDataFrame(columns=[
            'osm_id', 'osm_type', 'name', 'name_es', 'designation', 
            'protect_class', 'boundary', 'leisure', 'operator', 
            'website', 'wikidata', 'area_km2', 'geometry'
        ], crs='EPSG:4326')

def main():
    """
    Función principal que ejecuta todo el proceso.
    """
    print("=== Adquisición de Áreas Protegidas del Perú desde OSM ===\n")
    
    # 1. Construir consulta Overpass
    print("1. Construyendo consulta Overpass...")
    query = build_overpass_query()
    print("Consulta Overpass:")
    print(query)
    print()
    
    # 2. Obtener datos de OSM
    print("2. Obteniendo datos de OSM...")
    try:
        data = fetch_osm_data(query)
        elements = data.get('elements', [])
    except Exception as e:
        print(f"Error al obtener datos de OSM: {e}")
        
        # Intentar con una consulta más simple si falla
        print("\nIntentando con consulta simplificada...")
        simple_query = """
        [out:json][timeout:300][bbox:-18.5,-81.5,0.5,-68.5];
        (
          relation["boundary"="protected_area"];
          way["boundary"="protected_area"];
        );
        out geom;
        """
        try:
            data = fetch_osm_data(simple_query)
            elements = data.get('elements', [])
        except Exception as e2:
            print(f"Error también con consulta simplificada: {e2}")
            return
    
    if not elements:
        print("No se obtuvieron datos de OSM.")
        print("Esto puede deberse a:")
        print("- Falta de datos de áreas protegidas en OSM para Perú")
        print("- Problemas de conectividad con la API Overpass")
        print("- Filtros demasiado restrictivos")
        return
    
    # 3. Filtrar áreas protegidas
    print("3. Filtrando áreas protegidas...")
    filtered_elements = filter_protected_areas(elements)
    
    if not filtered_elements:
        print("No se encontraron áreas protegidas después del filtrado.")
        print("Elementos originales encontrados:")
        for element in elements[:5]:  # Mostrar primeros 5
            tags = element.get('tags', {})
            print(f"- ID: {element['id']}, Tipo: {element['type']}")
            print(f"  Tags: {dict(list(tags.items())[:3])}")  # Primeros 3 tags
        return
    
    # 4. Convertir a GeoDataFrame
    print("4. Convirtiendo a GeoDataFrame...")
    gdf = convert_to_geodataframe(filtered_elements)
    
    if gdf.empty:
        print("No se pudieron crear geometrías válidas.")
        return
    
    # 5. Mostrar estadísticas
    print(f"\n=== Estadísticas ===")
    print(f"Total de áreas protegidas: {len(gdf)}")
    print(f"Área total aproximada: {gdf['area_km2'].sum():.2f} km²")
    print(f"Área promedio: {gdf['area_km2'].mean():.2f} km²")
    
    print(f"\nDistribución por tipo de protección:")
    print(gdf['protect_class'].value_counts())
    
    print(f"\nPrimeras 5 áreas por tamaño:")
    top_areas = gdf.nlargest(5, 'area_km2')[['name', 'designation', 'area_km2']]
    print(top_areas.to_string(index=False))
    
    # 6. Guardar en GeoPackage
    print("\n5. Guardando en GeoPackage...")
    output_file = "areas_protegidas_solo_peru.gpkg"
    
    try:
        gdf.to_file(output_file, driver="GPKG")
        print(f"Archivo guardado exitosamente: {output_file}")
        
        # Verificar el archivo guardado
        gdf_loaded = gpd.read_file(output_file)
        print(f"Verificación: {len(gdf_loaded)} áreas protegidas guardadas")
        
    except Exception as e:
        print(f"Error al guardar el archivo: {e}")

if __name__ == "__main__":
    main()
# Out:
# === Adquisición de Áreas Protegidas del Perú desde OSM ===
#
# 1. Construyendo consulta Overpass...
# Consulta Overpass:
#
#     [out:json][timeout:300][maxsize:1073741824][bbox:-18.5,-81.5,0.5,-68.5];
#     (
#       // Consulta específica para áreas protegidas siguiendo estándares OSM
#       // Relaciones con boundary=protected_area (estándar principal)
#       relation["boundary"="protected_area"];
#
#       // Ways que forman límites de áreas protegidas
#       way["boundary"="protected_area"];
#
#       // Reservas naturales (clasificación leisure)
#       relation["leisure"="nature_reserve"];
#       way["leisure"="nature_reserve"];
#
#       // Cualquier elemento con clasificación de protección IUCN
#       relation["protect_class"~"^[1-6]$|^I[I-V]?$"];
#       way["protect_class"~"^[1-6]$|^I[I-V]?$"];
#
#       // Elementos específicos para Perú con designation
#       relation["designation"~"Parque Nacional|Reserva Nacional|Santuario Nacional|Santuario Histórico|Reserva Paisajística|Refugio de Vida Silvestre|Bosque de Protección|Coto de Caza|Zona Reservada|Área de Conservación"];
#       way["designation"~"Parque Nacional|Reserva Nacional|Santuario Nacional|Santuario Histórico|Reserva Paisajística|Refugio de Vida Silvestre|Bosque de Protección|Coto de Caza|Zona Reservada|Área de Conservación"];
#     );
#     (._;>;);
#     out geom;
#
#
# 2. Obteniendo datos de OSM...
# Realizando consulta a Overpass API (intento 1/3)...
# Servidor: https://overpass-api.de/api/interpreter
# Consulta exitosa. Elementos obtenidos: 528248
# 3. Filtrando áreas protegidas...
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protegido de Puengasi - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protegido de Puengasi - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protegido de Puengasi - protect_class: N/A, designation: N/A
# Aceptado: Bosque Municipal Protegido - protect_class: N/A, designation: N/A
# Aceptado: Isla Santay - protect_class: N/A, designation: N/A
# Aceptado: Isla Roncal - protect_class: N/A, designation: N/A
# Aceptado: Isla Chalaqueras - protect_class: N/A, designation: N/A
# Aceptado: Isla Correa - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Servidumbre Ecologica Privada Santa María - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Laguna de Cube - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Cashca Totoras - protect_class: N/A, designation: N/A
# Aceptado: Ciénaga de La Segua - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Bosque Petrificado Puyango - protect_class: N/A, designation: N/A
# Aceptado: Reserva Buenaventura - protect_class: N/A, designation: N/A
# Aceptado: Sayaqmarka - protect_class: 22, designation: N/A
# Aceptado: Bp016 (B. P. Casacay) - protect_class: N/A, designation: N/A
# Aceptado: Bp116 (B. P. Moro Moro) - protect_class: N/A, designation: N/A
# Aceptado: (Bosque Protector Rio Arenillas Presa Tahuin - protect_class: N/A, designation: N/A
# Aceptado: Parque Omaere - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Isla - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Arara do Rio Amonia - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Floresta Nacional de São Francisco - protect_class: 6, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Área Nacional de Recreación El Boliche - protect_class: N/A, designation: N/A
# Aceptado: Río Sumbay - protect_class: N/A, designation: N/A
# Aceptado: Río Ancusilla - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Reserva Las Tangaras - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Manglar La Boca - protect_class: N/A, designation: N/A
# Aceptado: Santuario de la Naturaleza y RENAMU Humedal Desembocadura Río Lluta - protect_class: N/A, designation: N/A
# Aceptado: Huembo - protect_class: N/A, designation: N/A
# Aceptado: Bosque Seco Lalo Loor - protect_class: N/A, designation: N/A
# Aceptado: Jama-Coaque Ecological Reserve - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Cuenca Alta del Río Nangaritza - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Tanlahua - protect_class: N/A, designation: N/A
# Aceptado: Área verde en Ladera - protect_class: N/A, designation: N/A
# Aceptado: Reserva de Bosque Natural del Sr. Gerardo Jácome - protect_class: N/A, designation: N/A
# Aceptado: COOPERATIVA JIMA LTDA. - protect_class: N/A, designation: N/A
# Aceptado: PAPALOMA CHARUM - protect_class: N/A, designation: N/A
# Aceptado: TOTORILLAS - protect_class: N/A, designation: N/A
# Aceptado: CUBILAN - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: RESERVA NATURAL CAZADEROS - protect_class: N/A, designation: N/A
# Aceptado: RESERVA NATURAL CAZADEROS - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Río Numpatakaime - protect_class: N/A, designation: N/A
# Aceptado: Milpe Gardens - protect_class: N/A, designation: N/A
# Aceptado: Santuario Nacional de Huayllay - protect_class: 3, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Bosque y Vegetacion Protectores Mondaña - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: LA MOLIENDA L - protect_class: N/A, designation: N/A
# Aceptado: Manglar - protect_class: N/A, designation: N/A
# Aceptado: Bosque y Vegetación Protectora Privado Hacienda Santa Rosa - protect_class: N/A, designation: N/A
# Aceptado: Bosque protector Zuleta - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Tulipe Pachijal - protect_class: 4, designation: N/A
# Aceptado: Area Nacional de Recreación Quimsacocha - protect_class: 21, designation: N/A
# Aceptado: Bosque Protector Mindo Nambillo - protect_class: N/A, designation: N/A
# Aceptado: Sillustani - protect_class: 22, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Cordillera del Cóndor - protect_class: 4, designation: N/A
# Aceptado: Refugio de Vida Silvestre El Zarza 2 - protect_class: 4, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Río Palenque Reserva de Bosque Tropical - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Peña Blanca - protect_class: 4, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Reserva Geobotánica Pululahua - protect_class: N/A, designation: N/A
# Aceptado: RANCHO GUAYMARAL - protect_class: N/A, designation: N/A
# Aceptado: Reserva Natural de la Sociedad Civil Zona de Biodiversidad La Loma - protect_class: 5, designation: N/A
# Aceptado: Reserva Natural de la Sociedad Civil Zona de Biodiversidad La Vega - protect_class: 5, designation: N/A
# Aceptado: Reserva Natural de la Sociedad Civil Zona de Biodiversidad El Triunfo - protect_class: 5, designation: N/A
# Aceptado: Reserva Natural de la Sociedad Civil Buena Vista - protect_class: 5, designation: N/A
# Aceptado: Reserva Natural de la Sociedad Civil La Gurrera - protect_class: 5, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Faldeo Norte del Morro de Arica - protect_class: 98, designation: N/A
# Aceptado: Ciudad de Quito - protect_class: 98, designation: N/A
# Aceptado: Parque Natural Pichiluli - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Amagusa - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Parque Ecológico Municipal Laguna El Mirador de Ventanilla - protect_class: N/A, designation: N/A
# Aceptado: Área Verde de la escuela "Juan Salinas" - protect_class: N/A, designation: N/A
# Aceptado: Bosque frutal del Colegio Ciudad de Valencia - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Cuenca Alta del Río Nangaritza - protect_class: N/A, designation: N/A
# Aceptado: AREA VERDE COMUNAL - protect_class: N/A, designation: N/A
# Aceptado: Jocotoco - Esmeraldas - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: DUNAS - protect_class: N/A, designation: N/A
# Aceptado: Sin nombre - protect_class: N/A, designation: N/A
# Aceptado: Reserva Ecologica El Paraiso - protect_class: N/A, designation: N/A
# Aceptado: COTOPAXIPUNGO - protect_class: N/A, designation: N/A
# Aceptado: Área de Protección para el gaviotín chico "Chacalluta" - protect_class: N/A, designation: N/A
# Aceptado: Circuito De Pichana - protect_class: N/A, designation: N/A
# Aceptado: Refugio de Vida Silvestre Isla Santa Clara - protect_class: N/A, designation: N/A
# Aceptado: Parque Nacional Sangay - protect_class: 98, designation: N/A
# Aceptado: Parque Nacional Yasuní - protect_class: 2, designation: N/A
# Aceptado: Reserva Ecológica Mache - Chindul - protect_class: 4, designation: N/A
# Aceptado: Parque Nacional Machalilla - protect_class: 2, designation: N/A
# Aceptado: Reserva Ecológica Manglares Churute - protect_class: N/A, designation: N/A
# Aceptado: Reserva Ecológica Arenillas - protect_class: N/A, designation: N/A
# Aceptado: Parque Binacional El Cóndor - protect_class: N/A, designation: N/A
# Aceptado: Parque Nacional Cajas - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Llanganates - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Cotopaxi - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Antisana - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Sumaco Napo-Galeras - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Cayambe-Coca - protect_class: 2, designation: N/A
# Aceptado: Reserva Ecológica Los Ilinizas - protect_class: N/A, designation: N/A
# Aceptado: Reserva Ecológica Cofán-Bermejo - protect_class: N/A, designation: N/A
# Aceptado: Reserva Ecológica Cotacachi-Cayapas - protect_class: 4, designation: N/A
# Aceptado: Refugio de Vida Silvestre El Zarza - protect_class: 4, designation: N/A
# Aceptado: Reserva Biológica El Quimi - protect_class: 4, designation: N/A
# Aceptado: Refugio de Vida Silvestre y Bosque de Proteccion Pasochoa - protect_class: N/A, designation: N/A
# Aceptado: Parque Nacional Madidi - protect_class: 2, designation: N/A
# Aceptado: Área Natural de Manejo Integrado Madidi - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional Sajama - protect_class: 2, designation: N/A
# Aceptado: Reserva Nacional de Vida Silvestre Amazónica Manuripi-Heath - protect_class: 6, designation: N/A
# Aceptado: Reserva Biológica Limoncocha - protect_class: N/A, designation: N/A
# Aceptado: Reserva de Producción Faunística Cuyabeno - protect_class: N/A, designation: N/A
# Aceptado: Bosques Protectores Acanamá-Guashapamba-Aguirre - protect_class: N/A, designation: N/A
# Aceptado: Río Arajuno - protect_class: N/A, designation: N/A
# Aceptado: Estación Biológica Jatun Sacha y Reserva Selva Viva - protect_class: N/A, designation: N/A
# Aceptado: Bajo Napo - protect_class: N/A, designation: N/A
# Aceptado: Reserva de Producción Faunística Chimborazo - protect_class: N/A, designation: N/A
# Aceptado: Reserva Nacional Pucacuro - protect_class: 6, designation: N/A
# Aceptado: Santuario Nacional Los Manglares de Tumbes - protect_class: 3, designation: N/A
# Aceptado: Reserva Nacional de Tumbes - protect_class: 6, designation: N/A
# Aceptado: Coto de Caza El Angolo - protect_class: 6, designation: N/A
# Aceptado: Bosque de Protección Pagaibamba - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional de Cutervo - protect_class: 2, designation: N/A
# Aceptado: Refugio de Vida Silvestre Laquipampa - protect_class: 4, designation: N/A
# Aceptado: Santuario Nacional Cordillera de Colán - protect_class: 3, designation: N/A
# Aceptado: Zona Reservada Santiago-Comaina - protect_class: 7, designation: N/A
# Aceptado: Zona Reservada Chancaybaños - protect_class: 7, designation: N/A
# Aceptado: Parque Nacional Yanachaga-Chemillén - protect_class: 2, designation: N/A
# Aceptado: Reserva Comunal El Sira - protect_class: 6, designation: N/A
# Aceptado: Bosque de Protección San Matías-San Carlos - protect_class: 6, designation: N/A
# Aceptado: Reserva Comunal Yanesha - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional Güeppi-Sekime - protect_class: 2, designation: N/A
# Aceptado: Reserva Nacional Allpahuayo Mishana - protect_class: 6, designation: N/A
# Aceptado: Reserva Nacional Pacaya Samiria - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional Cordillera Azul - protect_class: 2, designation: N/A
# Aceptado: Reserva Nacional Salinas y Aguada Blanca - protect_class: 6, designation: N/A
# Aceptado: Bosque Protector Cerro Pata de Pájaro - protect_class: 4, designation: N/A
# Aceptado: Parque Nacional Yacuri - protect_class: 2, designation: N/A
# Aceptado: Bosque Protector Jatumpamba-Jorupe - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Los Cedros - protect_class: N/A, designation: N/A
# Aceptado: Parque Nacional Natural Cahuinarí - protect_class: 2, designation: N/A
# Aceptado: Reserva Ecológica Comunal Loma Alta - protect_class: N/A, designation: N/A
# Aceptado: Area de Bosque y Vegetacion Protectores "Microcuenca Río Shio-Santa Bárbara" - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Pañacocha - protect_class: N/A, designation: N/A
# Aceptado: Reserva Comunal Bosque de Angashcola - protect_class: N/A, designation: N/A
# Aceptado: Refugio de Vida Silvestre Isla Corazón e Isla Fragata - protect_class: N/A, designation: N/A
# Aceptado: Reserva Biológica Tito Santos - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protegido San Juan - protect_class: N/A, designation: N/A
# Aceptado: Parque Nacional Natural Amacayacu - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Natural Río Puré - protect_class: 2, designation: N/A
# Aceptado: Líneas y Geoglifos de Nasca y Palpa - protect_class: 98, designation: N/A
# Aceptado: Parque Nacional Natural La Paya - protect_class: 2, designation: N/A
# Aceptado: Floresta Nacional do Macauã - protect_class: 6, designation: N/A
# Aceptado: Reserva Extrativista Chico Mendes - protect_class: 6, designation: N/A
# Aceptado: Floresta Nacional Mapiá-Inauini - protect_class: 6, designation: N/A
# Aceptado: Floresta Nacional de Santa Rosa do Purus - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional da Serra do Divisor - protect_class: 2, designation: N/A
# Aceptado: Reserva Extrativista do Alto Juruá - protect_class: 6, designation: N/A
# Aceptado: Reserva Extrativista do Cazumbá-Iracema - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional Podocarpus - protect_class: 2, designation: N/A
# Aceptado: Refugio de Vida Silvestre Manglares El Morro - protect_class: N/A, designation: N/A
# Aceptado: Reserva de Producción de Fauna Puntilla de Santa Elena - protect_class: N/A, designation: N/A
# Aceptado: Refugio de Vida Silvestre y Marino Costera Pacoche - protect_class: N/A, designation: N/A
# Aceptado: Parque Nacional Tingo María - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Huascarán - protect_class: 2, designation: N/A
# Aceptado: Área de Conservación Regional Choquequirao - protect_class: 6, designation: N/A
# Aceptado: Estação Ecológica Juami-Japurá - protect_class: 1, designation: N/A
# Aceptado: Estação Ecológica Rio Acre - protect_class: 1, designation: N/A
# Aceptado: Reserva Extrativista Riozinho da Liberdade - protect_class: 6, designation: N/A
# Aceptado: Reserva Extrativista do Alto Tarauacá - protect_class: 6, designation: N/A
# Aceptado: Siete Iglesias - protect_class: N/A, designation: N/A
# Aceptado: Reserva Comunal Tuntanaín - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional Ichigkat muja - Cordillera del Cóndor - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Otishi - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Alto Purús - protect_class: 2, designation: N/A
# Aceptado: Santuario Histórico de Machupicchu - protect_class: 3, designation: N/A
# Aceptado: Reserva Paisajística Nor Yauyos-Cochas - protect_class: 5, designation: N/A
# Aceptado: Área de Conservación Regional Sistema de Lomas de Lima Lomas de Ancón - protect_class: 6, designation: N/A
# Aceptado: Reserva Nacional de Junín - protect_class: 6, designation: N/A
# Aceptado: Reserva Nacional de Paracas - protect_class: 6, designation: N/A
# Aceptado: Reserva Paisajística Subcuenca del Cotahuasi - protect_class: 5, designation: N/A
# Aceptado: Parque Nacional Lauca - protect_class: 2, designation: N/A
# Aceptado: Reserva Nacional Las Vicuñas - protect_class: N/A, designation: N/A
# Aceptado: Monumento Natural Quebrada de Cardones - protect_class: N/A, designation: N/A
# Aceptado: Parque Nacional Natural Yaigojé Apaporis - protect_class: 2, designation: N/A
# Aceptado: Área de Conservación Regional Cordillera Escalera - protect_class: 6, designation: N/A
# Aceptado: Santuario Histórico Bosque de Pómac - protect_class: 3, designation: N/A
# Aceptado: Parque Nacional Río Abiseo - protect_class: 2, designation: N/A
# Aceptado: Zona Reservada Reserva Paisajística Cerro Khapia - protect_class: 7, designation: N/A
# Aceptado: Zona Arqueológica Monumental Pachacámac - protect_class: N/A, designation: N/A
# Aceptado: Reserva Biológica Cerro Plateado - protect_class: 1a, designation: N/A
# Aceptado: Parque Nacional Natural Sierra de Chiribiquete - protect_class: 2, designation: N/A
# Aceptado: Bien Nacional Protegido Cerro Poconchile - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Toachi Pilaton - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector de la Cuenca Alta del Rio Guayllabamba Area 1 - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Cushnirumi - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Piganta - protect_class: N/A, designation: N/A
# Aceptado: Areas del Interior de la cuenca del Rio Paute - protect_class: N/A, designation: N/A
# Aceptado: Reserva Natural Laipuna - protect_class: N/A, designation: N/A
# Aceptado: Bosque Protector Cuenca Alta del Río Nangaritza - protect_class: N/A, designation: N/A
# Aceptado: Patrimonio Forestal del Estado Unidad 9 Napo - protect_class: N/A, designation: N/A
# Aceptado: Ciudad del Cusco - protect_class: 98, designation: N/A
# Aceptado: Centro Histórico de Lima - protect_class: 98, designation: N/A
# Aceptado: Sitio Arqueológico de Chavín - protect_class: 98, designation: N/A
# Aceptado: Área de Bosque y Vegetación Protectora de la Subcuenca Alta del río León y Microcuencas de los ríos San Felipe de Oña y Shincata - protect_class: N/A, designation: N/A
# Aceptado: Reserva Nacional de Calipuy - protect_class: 6, designation: N/A
# Aceptado: Bosque de Protección Pui Pui - protect_class: 6, designation: N/A
# Aceptado: Santuario Nacional de Ampay - protect_class: 3, designation: N/A
# Aceptado: ACMUS El Pangui - protect_class: N/A, designation: N/A
# Aceptado: Reserva Nacional Matsés - protect_class: 6, designation: N/A
# Aceptado: Santuario Histórico de Chacamarca - protect_class: 3, designation: N/A
# Aceptado: Reserva Nacional del Titicaca - protect_class: 6, designation: N/A
# Aceptado: Reserva Nacional Tambopata - protect_class: 6, designation: N/A
# Aceptado: Isla Asia - protect_class: 6, designation: N/A
# Aceptado: Islas Ballestas - protect_class: 6, designation: N/A
# Aceptado: Isla Chao - protect_class: 6, designation: N/A
# Aceptado: Isla Chincha - protect_class: 6, designation: N/A
# Aceptado: Isla Lobos de Tierra - protect_class: 6, designation: N/A
# Aceptado: Isla Santa - protect_class: 6, designation: N/A
# Aceptado: Islas Cavinzas e Islotes Palominos - protect_class: 6, designation: N/A
# Aceptado: Islas Guañape - protect_class: 6, designation: N/A
# Aceptado: Islas Lobos de Afuera - protect_class: 6, designation: N/A
# Aceptado: Islas Macabí - protect_class: 6, designation: N/A
# Aceptado: Islas Pachacámac - protect_class: 6, designation: N/A
# Aceptado: Islote Corcovado - protect_class: 6, designation: N/A
# Aceptado: Islote Don Martín - protect_class: 6, designation: N/A
# Aceptado: Islote Grupo de Pescadores - protect_class: 6, designation: N/A
# Aceptado: Punta Atico - protect_class: 6, designation: N/A
# Aceptado: Punta Coles - protect_class: 6, designation: N/A
# Aceptado: Punta Colorado - protect_class: 6, designation: N/A
# Aceptado: Punta Culebras - protect_class: 6, designation: N/A
# Aceptado: Punta Hornillos - protect_class: 6, designation: N/A
# Aceptado: Punta La Chira - protect_class: 6, designation: N/A
# Aceptado: Punta La Litera - protect_class: 6, designation: N/A
# Aceptado: Punta Lomas - protect_class: 6, designation: N/A
# Aceptado: Punta Lomitas - protect_class: 6, designation: N/A
# Aceptado: Punta Salinas, Isla Huampanú e Isla Mazorca - protect_class: 6, designation: N/A
# Aceptado: Punta San Juan - protect_class: 6, designation: N/A
# Aceptado: Área Natural de Manejo Integrado Apolobamba - protect_class: 6, designation: N/A
# Aceptado: Santuario Nacional Megantoni - protect_class: 3, designation: N/A
# Aceptado: Santuario Nacional Lagunas de Mejía - protect_class: 3, designation: N/A
# Aceptado: Santuario Nacional Pampa Hermosa - protect_class: 3, designation: N/A
# Aceptado: Bosque de Protección de Alto Mayo - protect_class: 6, designation: N/A
# Aceptado: Bosque de Protección Aledaño a la Bocatoma del Canal Nuevo Imperial - protect_class: 6, designation: N/A
# Aceptado: Bosque de Protección Puquio Santa Rosa - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Sistema de Lomas de Lima Lomas de Villa María - protect_class: 6, designation: N/A
# Aceptado: Refugio de Vida Silvestre Bosques Nublados de Udima - protect_class: 4, designation: N/A
# Aceptado: Parque Nacional Bahuaja Sonene - protect_class: 2, designation: N/A
# Aceptado: Parque Nacional Sierra del Divisor - protect_class: 2, designation: N/A
# Aceptado: Coto de Caza Sunchubamba - protect_class: 6, designation: N/A
# Aceptado: Reserva Comunal Amarakaeri - protect_class: 6, designation: N/A
# Aceptado: Reserva Comunal Chayu Nain - protect_class: 6, designation: N/A
# Aceptado: Reserva Comunal Purús - protect_class: 6, designation: N/A
# Aceptado: Reserva Comunal Asháninka - protect_class: 6, designation: N/A
# Aceptado: Reserva Comunal Machiguenga - protect_class: 6, designation: N/A
# Aceptado: Reserva Comunal Airo Pai - protect_class: 6, designation: N/A
# Aceptado: Reserva Comunal Huimeki - protect_class: 6, designation: N/A
# Aceptado: Santuario Histórico de la Pampa de Ayacucho - protect_class: 3, designation: N/A
# Aceptado: Parque Nacional Yaguas - protect_class: 2, designation: N/A
# Aceptado: Zona Reservada Ancón - protect_class: 7, designation: N/A
# Aceptado: Reserva Nacional Illescas - protect_class: 6, designation: N/A
# Aceptado: Zona Reservada Río Nieva - protect_class: 7, designation: N/A
# Aceptado: Área de Conservación Regional Albúfera de Medio Mundo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Alto Nanay-Pintuyacu-Chambira - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Ampiyacu-Apayacu - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosque de Puya Raimondi–Titankayocc - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosque Huacrupe-La Calera - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosque Moyán-Palacio - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosques Secos de Salitral-Huarmaca - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosques Tropicales Estacionalmente Secos del Marañón - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Comunal Tamshiyacu Tahuayo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Humedales de Ventanilla - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Imiría - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Laguna de Huacachina - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Vilacota Maure - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Vista Alegre-Omia - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosques de Shunté y Mishollo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Maijuna Kichwa - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Angostura Faical - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Abra Málaga Thastayoc–Royal Cinclodes - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Mangamanguilla de la Asociación Agraria Manga Manga de Salitral - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Mantanay - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Comunal San Pablo-Catarata Gocta - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Copal Cuilungo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Monte Puyo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Páramos y Bosques Montanos San Miguel de Tabaconas - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Páramos y Bosques Montanos, Paraíso de la Comunidad Campesina San Felipe - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Arroyo Negro - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque de Neblina Aypate - Olleros - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque de Nogal y Bosque de Puentecilla - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque de Palmeras de la Comunidad Campesina Taulia Molinopampa - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Seco de Chililique Alto - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Seco de Colina Juan Velasco Alvarado - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Seco de la Comunidad Campesina César Vallejo de Palo Blanco - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Seco San Juan de los Guayaquiles - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosques de Cuyas Cuchayo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosques de Neblina y Páramos de Samanga - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosques Montanos y Páramos Chicuate – Chinguelas - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosques Montanos y Páramos de Huaricancha - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Chaparrí - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Choquechaca - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Copallín - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Ebio Kiabamene - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Hatun Queuña-Quishuarani Ccollana - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Hierba Buena - Allpayacu - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Huaylla Belén - Colcamar - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Huayllapa - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Ilish Pichacoto - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Japu - Bosque Ukumari Llaqta - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Jirishanca - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada La Pampa del Burro - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Lagunas y Páramos de Andinos de San José de Tapal - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Llamapampa - La Jalca - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Lomas de Atiquipa - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Los Bosques de Dotor, Hualtacal, Pueblo Libre, La Jardina y Chorro Blanco - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Los Bosques de Overal y Palo Blanco - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Los Chilchos - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Masheke - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Matoriato - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Microcuenca de Paria - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Pacllón - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Pampacorral - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Paraíso Natural Iwirati - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Pillco Grande - Bosque de Pumataki - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Páramos y Bosques Montanos de la Comunidad Campesina San Juan de Sallique - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Qosqoccahuarina - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Ronsoco Cocha - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada San Marcos - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada San Pedro de Chuquibamba - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Santa Catalina de Moza - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Sele Tecse - Lares Ayllu - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Siete Cataratas - Qanchis Paccha - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Tilacancha - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Uchumiri - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Yacila de Zamba - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Knoya - Supru - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Amazon Natural Park - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Natural El Cañoncillo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Abra Patricia - Alto Nieva - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Lomas del Cerro Campana - protect_class: 6, designation: N/A
# Aceptado: Zona Reservada Bosque de Zárate - protect_class: 7, designation: N/A
# Aceptado: Zona Reservada Cordillera Huayhuash - protect_class: 7, designation: N/A
# Aceptado: Reserva Nacional San Fernando - protect_class: 6, designation: N/A
# Aceptado: Reserva Nacional Pampa Galeras Bárbara D’Achille - protect_class: 6, designation: N/A
# Aceptado: Meseta de Marcahuasi - protect_class: N/A, designation: N/A
# Aceptado: Área de Conservación Regional Sistema de Lomas de Lima Lomas de Amancaes - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Sistema de Lomas de Lima Lomas de Carabayllo 1 - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Sistema de Lomas de Lima Lomas de Carabayllo 2 - protect_class: 6, designation: N/A
# Aceptado: El bosque protector Corazón de Oro - protect_class: N/A, designation: N/A
# Aceptado: Parque Metropolitano Paul Poblet Lind - protect_class: 6, designation: N/A
# Aceptado: Reserva Nacional de Lachay - protect_class: 6, designation: N/A
# Aceptado: Zona Histórica Intangible del Morro Solar - protect_class: 22, designation: N/A
# Aceptado: Refugio de Vida Silvestre Los Pantanos de Villa - protect_class: 4, designation: N/A
# Aceptado: 15 AREAS DEL INTERIOR DE LA CUENCA DEL RIO PAUTE - protect_class: N/A, designation: N/A
# Aceptado: Área de Conservación Privada La Niebla Forest - protect_class: 6, designation: N/A
# Aceptado: Humedal de Villa María - protect_class: 5, designation: N/A
# Aceptado: Concesión para Conservación Monte Cristo - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación El Breo - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Martín Sagrado - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Alto Huayabamba - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación El Gran Simacache - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Jardines Ángel del Sol - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Maquisapa - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Shitariyacu - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Las Tres Quebradas - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación El Paraiso de Yurilamas - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Ishichiwi - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Pucawicsa - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Valle del Biavo - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Huañipillo - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Ojecillo - Pucushcayacu - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Ojos de Agua - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Áreas Inundables Bajo Huallaga - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Bosque de Angaiza - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Yaku Kawsanapa - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Sacha Runa - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Los Bosques de Pailayco - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Los Bosques de Pacota - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Chuacullo - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación El Quinillal - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Reserva del Tunki - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Bosques del Sinaí - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Bosques Mirador del Huallaga - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Maná Hermoso - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Ampinakuna Sacha - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Bosques de Acobosay - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Bosques de Marona - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Sangapillal - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Tingana - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional de Ausangate - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Tres Cañones - protect_class: 6, designation: N/A
# Aceptado: Santuario Nacional Tabaconas Namballe - protect_class: 3, designation: N/A
# Aceptado: Área de Conservación Regional Bosques El Chaupe, Cunía y Chinchiquilla - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosque Montano de Carpish - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Amazon Shelter - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Aurora - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bahuaja - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bahuaja 1 - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Berlín - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bioparque Amazónico: Bosque de Huayo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Boa Wadack Dari - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Benjamín II - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Benjamín I - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Benjamín III - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Cachil - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque de Churumazú - protect_class: 6, designation: N/A
# Aceptado: Bosque Seco Amotape Private Conservation Area - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Botafogo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Buen Retiro - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Camino Verde Baltimore - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Cavernas de Leo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Chakra Educativa - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Checca - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Comunal Cujillo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Comunidad Nativa Tibi Playa I Zona Rio Ucayali - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Darshan Ashram - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada El Cortijo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada El Cortijo Centro Piedras - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada El Gato - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Espíritu del Monte - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Fundo Cadena - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Fundo Las Neblinas - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Fundo Rosita - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Fundo San Isidro El Labrador - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Gotas de Agua II - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Gotas de Agua I - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Habana Rural Inn - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Hakim & Cumorah - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Herman Dantas - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Huiquilla - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Inotawa-1 - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Inotawa-2 - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Juningue - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Kakiri Uka - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Kuntur Wachana - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada La Huerta del Chaparrí - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Lakshmi Amazónica - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Larga Vista II - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Larga Vista I - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Las Naranjas - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Las Panguanas 4 - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Las Panguanas 3 - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Las Panguanas 2 - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Las Panguanas 1 - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Machusaniaca II - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Machusaniaca I - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Milpuj - La Heredad - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Naturaleza Viva Ryo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Nuevo Amanecer - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Palmonte - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Panguana - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Pucunucho - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Pumawasi - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Refugio K'erenda Homet - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Refugio Lupuna - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Sabalillo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada San Antonio - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada San Juan Bautista - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Santuario de La Verónica - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Selva Botánica - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Selva Virgen - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Sumac Pacha - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Sumac Quilla - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Sumac Inti - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Tambo Ilusión - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Tambopata Eco Lodge - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Taypipiña - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Tutusima - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Wacan Numi - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Zaragoza - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Zoo Perú I - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Zoo Perú - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional Cerros de Amotape - protect_class: 2, designation: N/A
# Aceptado: Área de Conservación Regional Huaytapallana - protect_class: 6, designation: N/A
# Aceptado: Bosque de Piedra - protect_class: 99, designation: N/A
# Aceptado: Bosque de Piedra de Imata - protect_class: 7, designation: N/A
# Aceptado: Bosque de Piedra de Puruña - protect_class: 99, designation: N/A
# Aceptado: Complejo de Humedales del Abanico del Río Pastaza - protect_class: 98, designation: N/A
# Aceptado: Bofedales y Laguna de Salinas - protect_class: 98, designation: N/A
# Aceptado: Laguna del Indio - Dique de los Españoles - protect_class: 98, designation: N/A
# Aceptado: Lagunas Las Arreviatadas - protect_class: 98, designation: N/A
# Aceptado: Manglares de San Pedro de Vice - protect_class: 98, designation: N/A
# Aceptado: Santuario Nacional de Calipuy - protect_class: 3, designation: N/A
# Aceptado: Concesión para Conservación Río Los Amigos - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Amazon Rainforest - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Bosque Puyu Sacha - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Agricultores Ecológicos Santa Teresa - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Amarcu - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Pamau Nain - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Río La Novia - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Asociación Civil Aves del Perú - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Abra Patricia - Alto Nieva - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Alto Pilcomayo - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Asociación El Dragón - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Nature And Culture - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación APRODES - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Carla Sologuren Pastorelli - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación CEDIFACSA - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Inversiones Manu - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Chuncho Amazónico - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Reserva Haramba Queros Wachiperi - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Batsaikul - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Darwin Collazos - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Diego Valderrama - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Eduardo de la Cadena - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Cocha Cumanca - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Soqtapata - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Bosques para Estudio y Conservación de Biodiversidad - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Inversiones Maldonado - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Eraclia Diaz Quispe - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Erasmo Sumalave - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Amaru Mayo - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Rodal Semillero Tahuamanu - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Iguahuana – Bosques Secos del Delta - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Inotawa - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Javier Salazar - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Luis Tello Ochoa - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Lotty del Carmen - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Universidad Alas Peruanas - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Oxígeno para el Mundo Cuenca Río Tama - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Maconbo - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Remberto Reátegui Paredes - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Murosac - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Maximo Flores Chamorro - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Mayron García Oroche - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación AICON - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Rafael Cabrera Álvarez - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Antonio Fernandini Guerrero - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Cuenca Alta del Río Itaya - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación UNAMAD - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Universidad Nacional de Tumbes - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Inchatoshi Kametsha - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Económica Sostenible de la Amazonia - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Lago Preto Paredón - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Yessenia Sota Falcon - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Yurúa - protect_class: 6, designation: N/A
# Aceptado: Concesión para Conservación Arbio Perú - protect_class: 6, designation: N/A
# Aceptado: Bosque de Piedra de Choqolaqa - protect_class: 7, designation: N/A
# Aceptado: Bosque de Piedra de Laupay - protect_class: 7, designation: N/A
# Aceptado: Área de Conservación Privada Wayqecha - protect_class: 6, designation: N/A
# Aceptado: Parque Nacional del Manu - protect_class: 2, designation: N/A
# Aceptado: Humedal Lucre - Huacarpay - protect_class: 98, designation: N/A
# Aceptado: Lago Titicaca (Sector peruano) - protect_class: 98, designation: N/A
# Aceptado: Zona Arqueológica de Chan Chan - protect_class: 98, designation: N/A
# Aceptado: Centro Histórico de la Ciudad de Arequipa - protect_class: 98, designation: N/A
# Aceptado: Ciudad Sagrada de Caral-Supe - protect_class: 98, designation: N/A
# Aceptado: Bosque Protector Murocomba - protect_class: 4, designation: N/A
# Aceptado: Paisaje Cultural El Candelabro de Paracas - protect_class: 22, designation: N/A
# Aceptado: Reserva de Biósfera Huascarán - protect_class: 98, designation: N/A
# Aceptado: Reserva de Biósfera Gran Pajatén - protect_class: 98, designation: N/A
# Aceptado: Reserva de Biósfera Oxapampa-Asháninka-Yánesha - protect_class: 98, designation: N/A
# Aceptado: Reserva de Biósfera Bosques de Neblina-Selva Central - protect_class: 98, designation: N/A
# Aceptado: Reserva de Biósfera del Manu - protect_class: 98, designation: N/A
# Aceptado: Reserva de Biósfera del Noroeste Amotapes-Manglares - protect_class: 98, designation: N/A
# Aceptado: Parque Arqueológico Nacional de Pisaq - protect_class: 22, designation: N/A
# Aceptado: Parque Arqueológico Nacional de Pikillaqta - protect_class: 22, designation: N/A
# Aceptado: Parque Arqueológico Nacional de Sacsayhuaman - protect_class: 22, designation: N/A
# Aceptado: Parque Arqueológico Nacional de Pumamarka - protect_class: 22, designation: N/A
# Aceptado: Parque Arqueológico Nacional de Tipón - protect_class: 22, designation: N/A
# Aceptado: Parque Arqueológico Nacional de Vilcabamba - protect_class: 22, designation: N/A
# Aceptado: Área de Conservación Regional Chuyapi Urusayhua - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Comunidad Nativa San Jorge del Río Marañón - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Unchog - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Bosque Urum - protect_class: 6, designation: N/A
# Aceptado: Valle Sagrado de los Incas - protect_class: 22, designation: N/A
# Aceptado: Zona de Reserva Arqueológica Lineas y Geoglifos de Nasca - protect_class: 22, designation: N/A
# Aceptado: Paisaje Cultural Arqueológico Pinturas Rupestres de Corani y Macusani - protect_class: 22, designation: N/A
# Aceptado: Área de Conservación Privada Potsom Posho'll - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada San Luis - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Páramos y Bosques Montanos de Jaén y Tabaconas - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosques Secos del Marañón - protect_class: 6, designation: N/A
# Aceptado: Reserva Nacional Dorsal de Nasca - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Lomas de Quebrada Río Seco - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Codo del Pozuzo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Q’eros-Kosñipata - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Comunal Alto Tamaya-Abujao - protect_class: 6, designation: N/A
# Aceptado: Estuario de Virrilá - protect_class: 98, designation: N/A
# Aceptado: Reserva de Biósfera Transfronteriza Bosques de Paz - protect_class: 98, designation: N/A
# Aceptado: Área de Conservación Privada Ni Meraya - protect_class: 6, designation: N/A
# Aceptado: Reserva de Biósfera Avireri-Vraem - protect_class: 98, designation: N/A
# Aceptado: Área de Conservación Privada Comunidad Nativa Once de Agosto Río Ucayali - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Paraje Capiro Llaylla - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada San Lorenzo - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Regional Bosque Nublado Amaru-Huachocolpa-Chihuana - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Tambopata Eco Lodge I - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Misquiyaco - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Los Amigos - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Predio Collpapampa (Huadquiña-Mesada Chico) - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Nihii Eupa Papa Francisco - protect_class: 6, designation: N/A
# Aceptado: Bosque Protector Cerro Candelaria - protect_class: 6, designation: N/A
# Aceptado: Reserva Rio Verde - protect_class: N/A, designation: N/A
# Aceptado: Humedal Urbano Desembocadura del río Lluta - protect_class: 7, designation: N/A
# Aceptado: Área de Conservación Privada El Bosque Encantado de Sho'llet - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Suttoc y Pacchac - protect_class: 6, designation: N/A
# Aceptado: Huayllay National Sanctuary - protect_class: N/A, designation: N/A
# Aceptado: Parque nacional Río Negro-Sopladora - protect_class: 2, designation: N/A
# Aceptado: Área de Conservación Privada Fundo Miguel I - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Campo Verde - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada San Pablito II - protect_class: 6, designation: N/A
# Aceptado: Geoparque Colca y Volcanes de Andagua - protect_class: 98, designation: N/A
# Aceptado: Área de Conservación Privada Utco - protect_class: 6, designation: N/A
# Aceptado: Área de Conservación Privada Yasgolca-Santa Lucia, Montevideo - protect_class: 6, designation: N/A
# Aceptado: Bosque y Vegetación Protectora del Collay - protect_class: N/A, designation: N/A
# Aceptado: Reserva Marina La Puntilla - Playa Chinchorro - protect_class: 4, designation: N/A
# Aceptado: Reserva de Biosfera Bicentenario–Ayacucho - protect_class: 98, designation: N/A
# Aceptado: Reserva Nacional Mar Tropical de Grau - protect_class: 6, designation: N/A
# Aceptado: Reserva Biológica Colonso-Chalupas - protect_class: 4, designation: N/A
# Aceptado: Área de Conservación Regional Bosques Secos Interandinos de Cutervo - protect_class: 6, designation: N/A
#
# Elementos filtrados: 734 de 528248 originales
# 4. Convirtiendo a GeoDataFrame...
#
# === Estadísticas ===
# Total de áreas protegidas: 140
# Área total aproximada: 15436.31 km²
# Área promedio: 110.26 km²
#
# Distribución por tipo de protección:
# protect_class
#       119
# 4       5
# 5       5
# 2       3
# 22      2
# 98      2
# 6       2
# 3       1
# 21      1
# Name: count, dtype: int64
#
# Primeras 5 áreas por tamaño:
#                                            name designation    area_km2
#                Parque Nacional Natural Río Puré             2618.044593
#               Parque Nacional Natural Cahuinarí             1864.645076
#                                                             1519.542357
#                                                             1078.591371
# Bosque Protector Cuenca Alta del Río Nangaritza              886.201527
#
# 5. Guardando en GeoPackage...
# Archivo guardado exitosamente: peru_protected_areas1.gpkg
# Verificación: 140 áreas protegidas guardadas

# %%
#pip install fiona
# Out:
# Requirement already satisfied: fiona in c:\users\usuario\anaconda3\envs\geo_env\lib\site-packages (1.10.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\usuario\anaconda3\envs\geo_env\lib\site-packages (from fiona) (25.3.0)
# Requirement already satisfied: click~=8.0 in c:\users\usuario\anaconda3\envs\geo_env\lib\site-packages (from fiona) (8.2.1)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\usuario\anaconda3\envs\geo_env\lib\site-packages (from fiona) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\usuario\anaconda3\envs\geo_env\lib\site-packages (from fiona) (0.7.2)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\envs\geo_env\lib\site-packages (from click~=8.0->fiona) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import fiona

file_path = "peru_protected_areas1.gpkg"

# Listar capas usando fiona directamente
layers = fiona.listlayers(file_path)
print("Capas disponibles:", layers)
# Out:
# Capas disponibles: ['peru_protected_areas1']

# %%
import geopandas as gpd

gdf = gpd.read_file(file_path, layer=layers[0])
print(gdf.head())
# Out:
#      osm_id osm_type                          name name_es designation  \
# 0  31127953      way  Bosque Protegido de Puengasi
# 1  31127959      way  Bosque Protegido de Puengasi
# 2  31127962      way  Bosque Protegido de Puengasi
# 3  31142752      way    Bosque Municipal Protegido
# 4  33419728      way                   Isla Santay
#
#   protect_class        boundary         leisure operator website  wikidata  \
# 0                                nature_reserve
# 1                                nature_reserve
# 2                                nature_reserve
# 3                protected_area
# 4                protected_area  nature_reserve                   Q7420096
#
#     area_km2                                           geometry
# 0   0.163966  MULTIPOLYGON (((-78.50547 -0.23333, -78.50514 ...
# 1   0.381287  MULTIPOLYGON (((-78.50478 -0.23926, -78.50432 ...
# 2   0.058024  MULTIPOLYGON (((-78.4977 -0.24179, -78.49743 -...
# 3   0.111795  MULTIPOLYGON (((-78.50209 -0.11415, -78.50085 ...
# 4  21.871607  MULTIPOLYGON (((-79.84286 -2.25342, -79.8417 -...

# %%
pwd
# Out:
# 'c:\\Users\\usuario\\Documents\\GitHub\\Spatial_Analysis_of_Peru-s_Protected_Areas\\241878_hw4'
